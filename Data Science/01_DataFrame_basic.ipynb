# %%
# ## Anaconda가 설치 업데이트
# !conda update conda -y
# !conda update --all -y

import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
loan_df = pd.read_csv('data/loan.csv')
display(loan_df)
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 0    LP1003              Y                    N              4583
# 1    LP1005              Y                    Y              3000
# 2    LP1006              Y                    N              2583
# 3    LP1008              N                    N              6000
# 4    LP1011              Y                    Y              5417
# ..      ...            ...                  ...               ...
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area loan_status
# 0          128.4         Rural           N
# 1           66.0          City           Y
# ...

# %%
loan_df.head() #기본 5줄
# Out:
#   loan_id married_or_not self_employed_or_not  applicant_income  loan_amount  \
# 0  LP1003              Y                    N              4583        128.4
# 1  LP1005              Y                    Y              3000         66.0
# 2  LP1006              Y                    N              2583        120.5
# 3  LP1008              N                    N              6000        141.4
# 4  LP1011              Y                    Y              5417        267.4
#
#   property_area loan_status
# 0         Rural           N
# 1          City           Y
# 2          City           Y
# 3          City           Y
# 4          City           Y

# %%
loan_df.tail() #뒤에서 5줄
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 595  LP2974              Y                    N              3232
# 596  LP2979              Y                    N              4106
# 597  LP2983              Y                    N              8072
# 598  LP2984              Y                    N              7583
# 599  LP2990              N                    Y              4583
#
#      loan_amount property_area loan_status
# 595        108.6         Rural           Y
# 596         40.7         Rural           Y
# 597        253.4          City           Y
# 598        187.6          City           Y
# 599        133.2        Suburb           N

# %%
loan_df.shape
# Out:
# (600, 7)

# %%
loan_df.dtypes
# Out:
# loan_id                     str
# married_or_not              str
# self_employed_or_not        str
# applicant_income          int64
# loan_amount             float64
# property_area               str
# loan_status                 str
# dtype: object

# %%
loan_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_id               600 non-null    str
#  1   married_or_not        600 non-null    str
#  2   self_employed_or_not  568 non-null    str
#  3   applicant_income      600 non-null    int64
#  4   loan_amount           589 non-null    float64
#  5   property_area         600 non-null    str
#  6   loan_status           600 non-null    str
# dtypes: float64(1), int64(1), str(5)
# memory usage: 41.2 KB

# %%
loan_df.describe()
# Out:
#        applicant_income  loan_amount
# count        600.000000   589.000000
# mean        5412.161667   146.971307
# std         6160.362669    85.756442
# min          150.000000     9.200000
# 25%         2880.500000   100.700000
# 50%         3806.000000   128.000000
# 75%         5785.000000   168.300000
# max        81000.000000   700.300000

# %%
loan_df.describe(include='all')
# Out:
#        loan_id married_or_not self_employed_or_not  applicant_income  \
# count      600            600                  568        600.000000
# unique     600              2                    2               NaN
# top     LP1003              Y                    N               NaN
# freq         1            390                  488               NaN
# mean       NaN            NaN                  NaN       5412.161667
# std        NaN            NaN                  NaN       6160.362669
# min        NaN            NaN                  NaN        150.000000
# 25%        NaN            NaN                  NaN       2880.500000
# 50%        NaN            NaN                  NaN       3806.000000
# 75%        NaN            NaN                  NaN       5785.000000
# max        NaN            NaN                  NaN      81000.000000
#
#         loan_amount property_area loan_status
# count    589.000000           600         600
# ...

# %%
loan_df.sort_values(by='loan_amount' )
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 555  LP2840              N                    N              2378
# 13   LP1030              Y                    N              1299
# 91   LP1325              N                    N              3620
# 125  LP1482              Y                    Y              3459
# 542  LP2792              Y                    N              5468
# ..      ...            ...                  ...               ...
# 377  LP2243              Y                    N              3010
# 467  LP2533              Y                    N              2947
# 512  LP2697              N                    N              4680
# 538  LP2778              Y                    Y              6633
# 592  LP2960              Y                    N              2400
#
#      loan_amount property_area loan_status
# 555          9.2          City           N
# 13          17.5          City           Y
# ...

# %%
loan_df.sort_values(by='loan_amount', ascending=False)
# Out:
#     loan_id married_or_not self_employed_or_not  applicant_income  \
# 163  LP1585              Y                    N             51763
# 122  LP1469              N                    Y             20166
# 548  LP2813              Y                    Y             19484
# 147  LP1536              Y                    N             39999
# 359  LP2191              Y                    N             19730
# ..      ...            ...                  ...               ...
# 377  LP2243              Y                    N              3010
# 467  LP2533              Y                    N              2947
# 512  LP2697              N                    N              4680
# 538  LP2778              Y                    Y              6633
# 592  LP2960              Y                    N              2400
#
#      loan_amount property_area loan_status
# 163        700.3          City           Y
# 122        650.2          City           Y
# ...

# %%
## 엑셀 파일 불러오기
import pandas as pd
#기본 1번째 시트
load_excel_df = pd.read_excel('data/loan.xlsx')

#2번째 시트 명시
load_excel_df = pd.read_excel('data/loan.xlsx', sheet_name=1) #2번째 시트

load_excel_df
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2     Unnamed: 3        Unnamed: 4  \
# 0           NaN        NaN        NaN            NaN               NaN
# 1           NaN        NaN        NaN            NaN               NaN
# 2           NaN    loan_id    married  self_employed  applicant_income
# 3           NaN     LP1003          Y              N              4583
# 4           NaN     LP1005          Y              Y              3000
# ..          ...        ...        ...            ...               ...
# 598         NaN     LP2974          Y              N              3232
# 599         NaN     LP2979          Y              N              4106
# 600         NaN     LP2983          Y              N              8072
# 601         NaN     LP2984          Y              N              7583
# 602         NaN     LP2990          N              Y              4583
#
#       Unnamed: 5     Unnamed: 6   Unnamed: 7
# 0            NaN            NaN          NaN
# ...

# %%
#2번째 시트 B열부터 H열에 있는 데이터를 가져오기
load_excel_df = pd.read_excel('data/loan.xlsx', sheet_name=1, header=3, usecols='B:H')
load_excel_df
# Out:
#     loan_id married self_employed  applicant_income  loan_amount  \
# 0    LP1003       Y             N              4583        128.0
# 1    LP1005       Y             Y              3000         66.0
# 2    LP1006       Y             N              2583        120.0
# 3    LP1008       N             N              6000        141.0
# 4    LP1011       Y             Y              5417        267.0
# ..      ...     ...           ...               ...          ...
# 595  LP2974       Y             N              3232        108.0
# 596  LP2979       Y             N              4106         40.0
# 597  LP2983       Y             N              8072        253.0
# 598  LP2984       Y             N              7583        187.0
# 599  LP2990       N             Y              4583        133.0
#
#     property_area loan_status
# 0           Rural           N
# 1            City           Y
# 2            City           Y
# 3            City           Y
# ...
